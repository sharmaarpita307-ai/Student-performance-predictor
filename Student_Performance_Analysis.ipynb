# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("Student_Performance_Analysis.xlsx")

# %%
df = pd.DataFrame(data)
df.head(20)
# Out:
#    Student_ID  Gender  Department  Study_Hours  Attendance  Assignments  \
# 0        S001    Male         CSE            2          75            6
# 1        S002  Female          IT            4          85            8
# 2        S003    Male         ECE            3          80            7
# 3        S004  Female         CSE            5          92           10
# 4        S005    Male  Mechanical            1          65            4
# 5        S006  Female          IT            6          95           10
# 6        S007    Male         ECE            4          88            8
# 7        S008  Female         CSE            7          96           10
# 8        S009    Male  Mechanical            2          70            5
# 9        S010  Female          IT            5          90            9
# 10       S011    Male         CSE            3          78            6
# 11       S012  Female         ECE            6          93            9
# ...

# %%
df['Department'].unique()
# Out:
# <StringArray>
# ['CSE', 'IT', 'ECE', 'Mechanical']
# Length: 4, dtype: str

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Student_ID     20 non-null     str
#  1   Gender         20 non-null     str
#  2   Department     20 non-null     str
#  3   Study_Hours    20 non-null     int64
#  4   Attendance     20 non-null     int64
#  5   Assignments    20 non-null     int64
#  6   Midterm_Marks  20 non-null     int64
#  7   Final_Marks    20 non-null     int64
# dtypes: int64(5), str(3)
# memory usage: 1.4 KB

# %%
sns.scatterplot(data=df,x='Study_Hours',y='Final_Marks')

plt.show()

# %%
sns.scatterplot(data=df,x='Study_Hours',y='Final_Marks')
df
# Out:
#    Student_ID  Gender  Department  Study_Hours  Attendance  Assignments  \
# 0        S001    Male         CSE            2          75            6
# 1        S002  Female          IT            4          85            8
# 2        S003    Male         ECE            3          80            7
# 3        S004  Female         CSE            5          92           10
# 4        S005    Male  Mechanical            1          65            4
# 5        S006  Female          IT            6          95           10
# 6        S007    Male         ECE            4          88            8
# 7        S008  Female         CSE            7          96           10
# 8        S009    Male  Mechanical            2          70            5
# 9        S010  Female          IT            5          90            9
# 10       S011    Male         CSE            3          78            6
# 11       S012  Female         ECE            6          93            9
# ...

# %% [markdown]
# ## Lineplot

# %%
sns.lineplot(df,x='Study_Hours',y='Final_Marks')
plt.show()

# %% [markdown]
# ## Bar plot

# %%
sns.barplot(df,x='Department',y='Final_Marks')
plt.title('Average Final marks by dpartment')
# plt.xlabel('Department')
# plt.ylabel('Final_Marks')
plt.show()

# %% [markdown]
# # Count plot

# %%
sns.countplot(df,x='Department')
plt.show()

# %% [markdown]
# ## Box Plot

# %%
sns.boxplot(df,x='Gender',y='Final_Marks')
plt.show()

# %% [markdown]
# # Histogram
# ## How a mumerical variable is distributed and weher the most value is present

# %%
sns.histplot(df,x='Final_Marks',bins=8)
plt.show()

# %%
sns.violinplot(df,x='Gender',y='Final_Marks')
plt.show()
